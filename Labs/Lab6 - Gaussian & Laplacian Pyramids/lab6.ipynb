# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread("img.jpg")

# %%
layer = img.copy()
gaussian_pyramid_list = [layer]

for i in range(6):
  layer = cv2.pyrDown(layer)
  gaussian_pyramid_list.append(layer)
  cv2_imshow(layer)
# Out:
# <PIL.Image.Image image mode=RGB size=230x230>
# <PIL.Image.Image image mode=RGB size=115x115>
# <PIL.Image.Image image mode=RGB size=58x58>
# <PIL.Image.Image image mode=RGB size=29x29>
# <PIL.Image.Image image mode=RGB size=15x15>
# <PIL.Image.Image image mode=RGB size=8x8>

# %%
# This code is the manual solution but it doesnt work.

layer = gaussian_pyramid_list [5]
cv2_imshow(layer)
laplacian_pyramid_list = [layer]


for i in range(5, 0, -1):
  gaussian_extended = cv2.pyrUp(gaussian_pyramid_list[i])
  laplacian = cv2.subtract(gaussian_pyramid_list[i-1], gaussian_extended)
  cv2_imshow(laplacian)

cv2_imshow(img)

# %%
# This code was corrected by chatgbt. i guess it works.

layer = gaussian_pyramid_list [5]
cv2_imshow(layer)
laplacian_pyramid_list = [layer]


for i in range(5, 0, -1):
    gaussian_extended = cv2.pyrUp(gaussian_pyramid_list[i])
    gaussian_extended = gaussian_extended[:gaussian_pyramid_list[i-1].shape[0], :gaussian_pyramid_list[i-1].shape[1]]
    laplacian = cv2.subtract(gaussian_pyramid_list[i-1], gaussian_extended)
    cv2_imshow(laplacian)
# Out:
# <PIL.Image.Image image mode=RGB size=15x15>
# <PIL.Image.Image image mode=RGB size=29x29>
# <PIL.Image.Image image mode=RGB size=58x58>
# <PIL.Image.Image image mode=RGB size=115x115>
# <PIL.Image.Image image mode=RGB size=230x230>
# <PIL.Image.Image image mode=RGB size=460x460>
